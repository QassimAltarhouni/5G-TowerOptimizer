# %%
import os
import sys
sys.path.append("../src")

# %%
from data_loader import load_opencellid_data
from simulator import generate_users_within_bounds
from visualizer import plot_towers_on_map

# %%
file_path = "../data/germany.csv.gz"
df = load_opencellid_data(file_path)

print(df.columns.tolist())
print(df['radio'].value_counts())
df_5g = df[df['radio'].str.upper() == 'NR'].copy()
# Out:
# ['radio', 'mcc', 'net', 'area', 'cell', 'unit', 'lon', 'lat', 'range', 'samples', 'changeable', 'created', 'updated', 'averageSignal']
# radio
# LTE     166592
# GSM      45259
# UMTS     12804
# NR         463
# CDMA         1
# Name: count, dtype: int64

# %%
if df_5g.empty:
    print("❌ No 5G Network here!")
else:
    lat_min, lat_max = df_5g['lat'].min(), df_5g['lat'].max()
    lon_min, lon_max = df_5g['lon'].min(), df_5g['lon'].max()
    TIF_PATH = "../data/deu_ppp_2020_constrained.tif"
    users = generate_users_from_population_raster(TIF_PATH, sample_count=100000)

    m = plot_towers_on_map(
        df_5g,
        map_center=[(lat_min + lat_max)/2, (lon_min + lon_max)/2],
        df_users=users
    )

    # Create folder for my outputs
    os.makedirs("../outputs/figures", exist_ok=True)
    os.makedirs("../outputs/cleaned_data", exist_ok=True)

    # Get the country name
    file_base = os.path.basename(file_path).replace(".csv.gz", "")

    # Save my map and show
    m.save(f"../outputs/figures/{file_base}_5g_map.html")
    df_5g.to_csv(f"../outputs/cleaned_data/{file_base}_5g_towers.csv", index=False)
    users.to_csv(f"../outputs/cleaned_data/{file_base}_users.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       4 lat_min, lat_max = df_5g['lat'].min(), df_5g['lat'].max()
#       5 lon_min, lon_max = df_5g['lon'].min(), df_5g['lon'].max()
# ----> 7 users = generate_users_from_population_raster(TIF_PATH, sample_count=100000)
#       9 m = plot_towers_on_map(
#      10     df_5g,
#      11     map_center=[(lat_min + lat_max)/2, (lon_min + lon_max)/2],
#      12     df_users=users
#      13 )
#      15 # Create folder for my outputs
#
# NameError: name 'TIF_PATH' is not defined

# %%
    m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86a16ab968f68173e1177006d2a214b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86a16ab968f68173e1177006d2a214b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86a16ab968f68173e1177006d2a214b9 = L.map(
#                 &quot;map_86a16ab968f68173e1177006d2a214b9&quot;,
#                 {
#                     center: [51.033199999999994, 10.5233],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3dee0fff4cbb43a8a8ff9553ea9d447d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3dee0fff4cbb43a8a8ff9553ea9d447d.addTo(map_86a16ab968f68173e1177006d2a214b9);
#
#
#             var circle_marker_001d444bc6febdff5808ecde51d42115 = L.circleMarker(
#                 [53.7084, 11.4945],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86a16ab968f68173e1177006d2a214b9);
#
#
#         var popup_94027b0d8eff90fc9f8c6a3ba45cbd0b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_2cbee96d4f09215f56d20a1f2415be73 = $(`&lt;div id=&quot;html_2cbee96d4f09215f56d20a1f2415be73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Radio:&lt;/b&gt; NR&lt;br&gt;         &lt;b&gt;Range:&lt;/b&gt; 1000 m&lt;br&gt;         &lt;b&gt;Samples:&lt;/b&gt; 11&lt;br&gt;         &lt;b&gt;Signal:&lt;/b&gt; 0         &lt;/div&gt;`)[0];
#                 popup_94027b0d8eff90fc9f8c6a3ba45cbd0b.setContent(html_2cbee96d4f09215f56d20a1f2415be73);
#
#
#
#         circle_marker_001d444bc6febdff5808ecde51d42115.bindPopup(popup_94027b0d8eff90fc9f8c6a3ba45cbd0b)
#         ;
#
#
#
#
#             var circle_marker_ae28d92c9ba119e23a59267aec64f1f1 = L.circleMarker(
#                 [52.5734, 13.4324],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86a16ab968f68173e1177006d2a214b9);
#
#
#         var popup_9a31ec460bd03413bcfdbc4dc5c59dfe = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_4a1707fe4e4078380cee65f80a28a3b1 = $(`&lt;div id=&quot;html_4a1707fe4e4078380cee65f80a28a3b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Radio:&lt;/b&gt; NR&lt;br&gt;         &lt;b&gt;Range:&lt;/b&gt; 7630 m&lt;br&gt;         &lt;b&gt;Samples:&lt;/b&gt; 17&lt;br&gt;         &lt;b&gt;Signal:&lt;/b&gt; 0         &lt;/div&gt;`)[0];
#                 popup_9a31ec460bd03413bcfdbc4dc5c59dfe.setContent(html_4a1707fe4e4078380cee65f80a28a3b1);
#
#
#
#         circle_marker_ae28d92c9ba119e23a59267aec64f1f1.bindPopup(popup_9a31ec460bd03413bcfdbc4dc5c59dfe)
#         ;
#
#
#
#
#             var circle_marker_aa831e99f2aa9341ca9f1e0d1558bd0e = L.circleMarker(
#                 [52.5787, 13.4254],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86a16ab968f68173e1177006d2a214b9);
#
#
#         var popup_565825cc4adffe0a0d4448e970efa60a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_b68742995f63799260a8ebd8fb9a797c = $(`&lt;div id=&quot;html_b68742995f63799260a8ebd8fb9a797c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Radio:&lt;/b&gt; NR&lt;br&gt;         &
